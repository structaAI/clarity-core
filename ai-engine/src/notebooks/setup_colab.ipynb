# %%
import os

# Set local path to your dataset directory (update this to your actual local path)
DRIVE_BASE_PATH = 'COCO_denoising'  # Update this name if needed, e.g., to an absolute path like 'D:/data/COCO_denoising'
HR_RAW = os.path.join(DRIVE_BASE_PATH, 'clean_train')
LR_RAW = os.path.join(DRIVE_BASE_PATH, 'degraded_train2017')

# Verify the connection
print(f"Total HR images: {len(os.listdir(HR_RAW))}")
print(f"Total Degraded: {len(LR_RAW)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 import os
#       4 # Mount your personal drive
#
# ModuleNotFoundError: No module named 'google'
